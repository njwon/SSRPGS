# %% [markdown]
# # Cipher

# %% [markdown]
# ```C#
# // I worked here: https://dotnetfiddle.net
# // Original C# code to understand whats going on
# using System;
# using System.IO;
# using System.Security.Cryptography;
# using System.Linq;
# using System.Text;
#
# public class Program {
#     public static string text = "Catalyst";
#     public static string passPhrase = "peekabeyoufoundme";
#
#     public static void Main() {
#         string encr = Encrypt(text, passPhrase);
#         string decr = Decrypt(encr, passPhrase);
#
#         Console.WriteLine("Encrypted: " + encr);
#         Console.WriteLine("Decrypted: " + decr);
#     }
#
#     private static byte[] Generate256BitsOfRandomEntropy() {
#         // It's supposed to generate crypto-resistant entropy,
#         // but that's not why we're here.
#         var zeros = new byte[32];  // 32 Bytes will give us 256 bits of zeros.
#         return zeros;
#     }
#
#     public static string Encrypt(string plainText, string passPhrase)
#     {
#         byte[] array = Generate256BitsOfRandomEntropy();   // May be any [32] bytes -> salt
#         byte[] array2 = Generate256BitsOfRandomEntropy();  // May be any [32] bytes -> rgbIV
#         byte[] bytes = Encoding.UTF8.GetBytes(plainText);
#         byte[] bytes2 = new Rfc2898DeriveBytes(passPhrase, array, 1000).GetBytes(32);
#         string result;
#
#         // Console.WriteLine("array: " + string.Join(", ", array));
#
#         using (RijndaelManaged rijndaelManaged = new RijndaelManaged()) {
#             rijndaelManaged.BlockSize = 256;
#             rijndaelManaged.Mode = CipherMode.CBC;
#             rijndaelManaged.Padding = PaddingMode.PKCS7;
#             using (ICryptoTransform cryptoTransform = rijndaelManaged.CreateEncryptor(bytes2, array2)) {
#                 using (MemoryStream memoryStream = new MemoryStream()) {
#                     using (CryptoStream cryptoStream = new CryptoStream(memoryStream, cryptoTransform, CryptoStreamMode.Write)) {
#                         cryptoStream.Write(bytes, 0, bytes.Length);
#                         cryptoStream.FlushFinalBlock();
#                         byte[] inArray = array.Concat(array2).ToArray<byte>().Concat(memoryStream.ToArray()).ToArray<byte>();
#                         memoryStream.Close();
#                         cryptoStream.Close();
#                         result = Convert.ToBase64String(inArray);
#                     }
#                 }
#             }
#         }
#         return result;
#     }
#
#     public static string Decrypt(string cipherText, string passPhrase) {
#         byte[] array = Convert.FromBase64String(cipherText);
#         byte[] salt = array.Take(32).ToArray<byte>();
#         byte[] rgbIV = array.Skip(32).Take(32).ToArray<byte>();
#         byte[] array2 = array.Skip(64).Take(array.Length - 64).ToArray<byte>();
#         byte[] bytes = new Rfc2898DeriveBytes(passPhrase, salt, 1000).GetBytes(32);
#         string @string;
#
#         // Console.WriteLine(string.Join(", ", array));
#
#         using (RijndaelManaged rijndaelManaged = new RijndaelManaged()) {
#             rijndaelManaged.BlockSize = 256;
#             rijndaelManaged.Mode = CipherMode.CBC;
#             rijndaelManaged.Padding = PaddingMode.PKCS7;
#             using (ICryptoTransform cryptoTransform = rijndaelManaged.CreateDecryptor(bytes, rgbIV)) {
#                 using (MemoryStream memoryStream = new MemoryStream(array2)) {
#                     using (CryptoStream cryptoStream = new CryptoStream(memoryStream, cryptoTransform, CryptoStreamMode.Read)) {
#                         byte[] array3 = new byte[array2.Length];
#                         int count = cryptoStream.Read(array3, 0, array3.Length);
#                         memoryStream.Close();
#                         cryptoStream.Close();
#                         @string = Encoding.UTF8.GetString(array3, 0, count);
#                     }
#                 }
#             }
#         }
#         return @string;
#     }
# }
# ```

# %%
cipher = "..."
password = "peekabeyoufoundme"
text = "Hello world!"

# %%
# !pip3 install pprp==0.2.5

import pprp
import base64

def CBC_decrypt(key, s, iv, block_size=32):
    r = pprp.crypto_3.rijndael(key, block_size=block_size)

    i = 0
    for block in s:
        decrypted = r.decrypt(block)
        decrypted = xor(decrypted, iv)  
        iv = block

        yield decrypted
        i += 1

def CBC_encrypt(key, s, iv, block_size=32):
    r = pprp.crypto_3.rijndael(key, block_size=block_size)

    i = 0
    for block in s:
        len_ = len(block)
        if len_ < block_size:
            padding_size = block_size - len_
            block += (chr(padding_size) * padding_size).encode('ASCII')
        
        xored = xor(block, iv)
        encrypted = r.encrypt(xored)
        iv = encrypted

        yield encrypted
        i += 1

def xor(block, iv):
    result = [(a ^ b) for (a, b) in zip(block, iv)]
    return bytes(result)

def printbytes(name, array):
    print(name, ", ".join([str(i) for i in array]))

# Encryption
joke = "MADE/BY/CATALYST/42/"
joke = bytes(base64.b64decode(joke))

salt = joke + bytes([0]*(32 - len(joke)))
rgbIV = bytes([0]*32)
array2 = list(bytes("TEXT".encode("utf-8")))
kbytes = pprp.pbkdf2(password.encode('utf-8'), bytes(salt), 32, iterations=1000)

blocksize = 32
sg = pprp.data_source_gen(array2, blocksize)
dg = CBC_encrypt(kbytes, sg, rgbIV, blocksize)
encrypted = pprp.encrypt_sink(dg)

encrypted = base64.b64encode(salt + rgbIV + encrypted)
print(encrypted)
cipher = encrypted

# Decryption
array = list(bytearray(base64.b64decode(cipher)))
salt = array[:32]
rgbIV = array[32:64]
array2 = array[64:]
kbytes = pprp.pbkdf2(password.encode('utf-8'), bytes(salt), 32, iterations=1000)

blocksize = 32
sg = pprp.data_source_gen(array2, blocksize)
dg = CBC_decrypt(kbytes, sg, rgbIV, blocksize);
decrypted = pprp.decrypt_sink(dg, blocksize).decode("utf-8")
print(decrypted)
# Out:
# b'MADE/BY/CATALYST/42/AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAABW9UFnavuNrJnPO/DEtQSUeqWF8dg9OTmwNOX76czqY'
# TEXT

# %% [markdown]
# # Tests

# %%
cipher = "..."

array = list(bytearray(base64.b64decode(cipher)))
salt = array[:32]
rgbIV = array[32:64]
array2 = array[64:]
kbytes = pprp.pbkdf2(password.encode('utf-8'), bytes(salt), 32, iterations=1000)

blocksize = 32
sg = pprp.data_source_gen(array2, blocksize)
dg = CBC_decrypt(kbytes, sg, rgbIV, blocksize);
decrypted = pprp.decrypt_sink(dg, blocksize).decode("utf-8")

decrypted
# Out:
# '{version:3.60.2,rng:297931346,hero_settings:{lastSaveTime:05/07/2024 13:36:00,playerName:simple one,bigHead:False},progress_flags:{flags:[show_workstation,show_items,show_stone,show_wood,rocky_plateau_1,show_banner,deadwood_valley_1,PATCH_ELEMENT_DAMAGE_v2100,PATCH_HAMMERS_v2110,PATCH_LONG_SWORDS_v2140]},quest_data:{available:[deadwood_valley,rocky_plateau],star_levels:{},aspiring_star_ids:[],aspiring_stars:[],has_seen:[find_shelter,rocky_plateau,build_door,deadwood_valley,build_workstation,craft_shovel,craft_hatchet,prospect_cliff],has_played:[rocky_plateau,find_shelter,build_door,deadwood_valley,build_workstation,craft_hatchet,craft_shovel,prospect_cliff],has_completed:[rocky_plateau,find_shelter,build_door,deadwood_valley,build_workstation,craft_hatchet,craft_shovel,prospect_cliff],stats:[],skullnata:05/05/2024 10:58:08},inventory_data:{Stone:3,Wood:3,itms:[{id:dirty_sword,da:{hI:True,rng:0}},{id:stones,da:{hI:True,rng:0}},{id:hatchet_lv1,da:{hI:True,rng:0}},{id:shovel_lv1,da:{hI:True,rng:0}},{id:sight_stone,da:{hI:True,rng:0}}],rightH:stones_lv1,itmsSeen:[sight_stone_lv1,stones_lv1,hatchet_lv1_lv1,shovel_lv1_lv1,dirty_sword_lv1]},cosmetics:{},treasure_factory:{uniqueDate:04/30/2024 12:10:33,crystalDate:04/30/2024 12:10:33,goldDate:04/20/2024 12:10:33},ui_state:{screen:QuestScreen,quest_scroll_y:0,workstation_scroll_y:0,items_scroll_y:1},shop_states:{ids:[],hasSeenShopkeeper:False,totalPurchases:0},crypt_intro:{timesPlayed:0,nextTreasureAvailableDate:05/05/2024 12:10:33},xp:{currentLevel:0,currentXP:0},ouroboros:{hasBeenTapped:False},utility_belt:{loadouts:[]},craft_book:{discovered_crafts:[]},achievements:{FOES_DEFEATED:1},mutator:{seed:1830886142},events:{sIds:[]},custom_quests:{ftueStep:UnlockBasicQuests,revealed:[],active:[],counter:0,completedCount:0,nextSpawnDate:05/05/2024 12:10:33,epicSpawnPending:False,basicQuestDate:05/05/2024 00:00:00},weekly_quest:{questCount:0,expiration:05/05/2024 12:10:33},goals:{skeleton_arm:{goal:-1,progress:0},blade_of_god:{goal:-1,progress:0},cult_mask:{goal:-1,progress:0},fire_talisman:{goal:-1,progress:0},aether_talisman:{goal:-1,progress:0}},subs:{},prom:{},leaderboards:{pId:""},mind_stone:{enabled:False,program:[// В рабочем состоянии Камень разума постоянно,// выполняет данные ему указания.,// Указания должны быть написаны на,// Камнескрипте.,// Узнайте больше на:,// StoneStoryRPG.com/stonescript,// - Мудрец Безерра,"",?hp < 7,"  activate potion",?loc = caves,"  equipL sword","  equipR shield","  ?foe = boss","    equip crossbow"],saveId:1}}'

# %%
# Encryption
decrypted = """{version:3.60.2,rng:297931346,hero_settings:{lastSaveTime:05/07/2024 13:36:00,playerName:simple one,bigHead:False},progress_flags:{flags:[show_workstation,show_items,show_stone,show_wood,rocky_plateau_1,show_banner,deadwood_valley_1,PATCH_ELEMENT_DAMAGE_v2100,PATCH_HAMMERS_v2110,PATCH_LONG_SWORDS_v2140]},quest_data:{available:[deadwood_valley,rocky_plateau],star_levels:{},aspiring_star_ids:[],aspiring_stars:[],has_seen:[find_shelter,rocky_plateau,build_door,deadwood_valley,build_workstation,craft_shovel,craft_hatchet,prospect_cliff],has_played:[rocky_plateau,find_shelter,build_door,deadwood_valley,build_workstation,craft_hatchet,craft_shovel,prospect_cliff],has_completed:[rocky_plateau,find_shelter,build_door,deadwood_valley,build_workstation,craft_hatchet,craft_shovel,prospect_cliff],stats:[],skullnata:05/05/2024 10:58:08},inventory_data:{Stone:3000000,Wood:30042000,itms:[{id:dirty_sword,da:{hI:True,rng:0}},{id:stones,da:{hI:True,rng:0}},{id:hatchet_lv1,da:{hI:True,rng:0}},{id:shovel_lv1,da:{hI:True,rng:0}},{id:sight_stone,da:{hI:True,rng:0}}],rightH:stones_lv1,itmsSeen:[sight_stone_lv1,stones_lv1,hatchet_lv1_lv1,shovel_lv1_lv1,dirty_sword_lv1]},cosmetics:{},treasure_factory:{uniqueDate:04/30/2024 12:10:33,crystalDate:04/30/2024 12:10:33,goldDate:04/20/2024 12:10:33},ui_state:{screen:QuestScreen,quest_scroll_y:0,workstation_scroll_y:0,items_scroll_y:1},shop_states:{ids:[],hasSeenShopkeeper:False,totalPurchases:0},crypt_intro:{timesPlayed:0,nextTreasureAvailableDate:05/05/2024 12:10:33},xp:{currentLevel:120,currentXP:0},ouroboros:{hasBeenTapped:False},utility_belt:{loadouts:[]},craft_book:{discovered_crafts:[]},achievements:{FOES_DEFEATED:1},mutator:{seed:1830886142},events:{sIds:[]},custom_quests:{ftueStep:UnlockBasicQuests,revealed:[],active:[],counter:0,completedCount:0,nextSpawnDate:05/05/2024 12:10:33,epicSpawnPending:False,basicQuestDate:05/05/2024 00:00:00},weekly_quest:{questCount:0,expiration:05/05/2024 12:10:33},goals:{skeleton_arm:{goal:-1,progress:0},blade_of_god:{goal:-1,progress:0},cult_mask:{goal:-1,progress:0},fire_talisman:{goal:-1,progress:0},aether_talisman:{goal:-1,progress:0}},subs:{},prom:{},leaderboards:{pId:""},mind_stone:{enabled:False,program:[// В рабочем состоянии Камень разума постоянно,// выполняет данные ему указания.,// Указания должны быть написаны на,// Камнескрипте.,// Узнайте больше на:,// StoneStoryRPG.com/stonescript,// - Мудрец Безерра,"",?hp < 7,"  activate potion",?loc = caves,"  equipL sword","  equipR shield","  ?foe = boss","    equip crossbow"],saveId:1}}"""

joke = "MADE/BY/CATALYST/42/"
joke = bytes(base64.b64decode(joke))

salt = joke + bytes([0]*(32 - len(joke)))
rgbIV = bytes([0]*32)
array2 = list(bytes(decrypted.encode("utf-8")))
kbytes = pprp.pbkdf2(password.encode('utf-8'), bytes(salt), 32, iterations=1000)

blocksize = 32
sg = pprp.data_source_gen(array2, blocksize)
dg = CBC_encrypt(kbytes, sg, rgbIV, blocksize)
encrypted = pprp.encrypt_sink(dg)

encrypted = base64.b64encode(salt + rgbIV + encrypted)
print(encrypted)
cipher = encrypted
# Out:
# b'...'

# %% [markdown]
# # Slim JSON

# %%
from cryptors import encrypt, decrypt
from re import finditer
from string import ascii_letters
import json

from cryptors import decrypt

# save_file = "/Users/catalyst/Library/Application Support/Martian Rex, Inc_/Stone Story/76561198831663836/primary_save.txt"
save_file = "save.txt"

def insert(text, value, i):
    return text[:i] + value + text[i:]

def jsonize(text):
    text = text.replace('\n\t', '\n')

    # Escape array values (colons)
    shift = 0
    for m in finditer(r"\[([^{]+?,)*?[^{]*?\]", text):
        array = m.group(0).replace("\n", '')
        start_len = len(m.group(0))
        inner_shift = 0
        for match in finditer(r"\".*?\"|[^,\[\]]+", array):
            start = match.start() + inner_shift
            end = match.end() + inner_shift

            value = array[start:end]

            if value[0] != '"':
                array = f'{array[:start]}"{value}"{array[end:]}'
                inner_shift += 2
        
        start = m.start() + shift
        end = m.end() + shift
        text = f'{text[:start]}{array}{text[end:]}'
        shift += -start_len + len(array)
        
    # Add quotes to all values
    shift = 0
    for match in finditer(r"\".*?\"|[^{}\[\],\n\"]+", text):
        start = match.start() + shift
        end = match.end() + shift

        value = text[start:end]
        if value[0] == '"':
            continue

        if value.count(":") == 0:
            text = f'{text[:start]}"{value}"{text[end:]}'
            shift += 2

        elif value.count(":") >= 1:
            key, value = value.split(":", 1)

            if not value or value[0] == '"' or value.isdigit():
                text = f'{text[:start]}"{key}":{value}{text[end:]}'
                shift += 2
            else:
                text = f'{text[:start]}"{key}":"{value}"{text[end:]}'
                shift += 4
    
    return text

def jsave(code):
    with open("formatted.json", "w") as j:
        j.write(json.dumps(code, indent=4))

def Jsave(text):
    with open("formatted.json", "w") as j:
        j.write(text)

with open(save_file, "r") as file:
    save = file.read()

    jsonized = jsonize(save)
    save_json = json.loads(jsonized)

    for value in save_json:
        if value.startswith("save_file_") and value != "save_file_last_id":
            progress_data = decrypt(save_json[value]["progress_data"])
            progress_json = jsonize(progress_data)
            save_json[value]["progress_data"] = json.loads(progress_json)

    jsave(save_json)

save_json
# Out:
# {'save_file_last_id': 42,
#  'save_file_42': {'save_id': 42,
#   'uId': 'W52FT4',
#   'cId': 'TALQBW',
#   'timestamp': '05/09/2024 17:26:32',
#   'display_name': 'Primary Game',
#   'version': '3.60.3',
#   'is_debug': 'False',
#   'player_name': 'Catalyst',
#   'player_xp': 0,
#   'player_level': 60,
#   'total_stars': 120,
#   'gearPoints': 28120,
#   'left_item_id': '',
#   'left_item_data': '',
#   'right_item_id': '',
#   'right_item_data': '',
#   'big_head': 'False',
#   'hqs': 'True',
#   'progress_data': {'version': '3.60.3',
#    'rng': 2128503496,
#    'hero_settings': {'lastSaveTime': '05/09/2024 17:26:32',
#     'playerName': 'Catalyst',
#     'bigHead': 'False'},
#    'progress_flags': {'flags': ['show_workstation',
#      'show_items',
#      'show_stone',
#      'show_wood',
#      'show_tar',
#      'show_bronze',
#      'show_xi',
#      'utility_belt',
#      'rocky_plateau_1',
#      'show_banner',
#      'got_metal_2_from_boulder',
#      'deadwood_valley_1',
#      'ranting_tree_died',
#      'got_treasure_ranting_tree',
#      'ftue_equip_sword',
#      'dysangelos_intro_complete',
#      'waterfall',
#      'waterfall_dialog_seen',
#      'quarterstaff_enabled',
#      'shop_buy_all',
#      'bolesh_giant_treasure',
#      'shop_keeper_loyal',
#      'has_upgraded_cauldron',
#      'broken_bridge',
#      'dysangelos_bearer_intro',
#      'dysangelos_bearer_unmaking_you',
#      'dysangelos_bearer_return_to_stone',
#      'PATCH_ELEMENT_DAMAGE_v2100',
#      'PATCH_HAMMERS_v2110',
#      'PATCH_LONG_SWORDS_v2140',
#      'dysangelos_bearer_believe_in_light',
#      'dysangelos_perfected_intro',
#      'roof_overhead_first_time_reward',
#      'bad_business_nametag',
#      'wild_ride_skeleton_arm',
#      'skeleton_arm_ftue',
#      'titanic_accord_blade_of_god',
#      'freetkts2']},
#    'quest_data': {'available': ['temple',
#      'cross_bridge',
#      'icy_ridge',
#      'bronze_gate',
#      'bronze_mine',
#      'cross_deadwood_river',
#      'undead_crypt',
#      'undead_crypt_intro',
#      'uulaa_shop',
#      'mushroom_shop',
#      'fungus_forest',
#      'waterfall',
#      'caustic_caves',
#      'deadwood_valley',
#      'rocky_plateau',
#      'mutate',
#      'automate',
#      'fuse_enchantments',
#      'break_apart_items',
#      'brew_potion',
#      'anvil'],
#     'star_levels': {'temple': 15,
#      'icy_ridge': 15,
#      'bronze_mine': 15,
#      'undead_crypt': 15,
#      'fungus_forest': 15,
#      'caustic_caves': 15,
#      'deadwood_valley': 15,
#      'rocky_plateau': 15},
#     'aspiring_star_ids': ['fungus_forest',
#      'temple',
#      'deadwood_valley',
#      'caustic_caves',
#      'icy_ridge',
#      'undead_crypt',
#      'bronze_mine',
#      'rocky_plateau'],
#     'aspiring_stars': ['16', '16', '16', '16', '16', '16', '16', '16'],
#     'has_seen': ['find_shelter',
#      'rocky_plateau',
#      'build_door',
#      'deadwood_valley',
#      'build_workstation',
#      'craft_shovel',
#      'craft_hatchet',
#      'prospect_cliff',
#      'clean_sword',
#      'upgrade_workstation_2',
#      'craft_canoe',
#      'dig_cave',
#      'caustic_caves',
#      'craft_anvil_hammer',
#      'craft_anvil',
#      'anvil',
#      'cross_deadwood_river',
#      'bronze_gate',
#      'upgrade_workstation_3',
#      'craft_grappling_hook',
#      'utility_belt',
#      'waterfall',
#      'fungus_forest',
#      'undead_crypt_intro',
#      'undead_crypt',
#      'bronze_mine',
#      'upgrade_workstation_4',
#      'make_cauldron',
#      'icy_ridge',
#      'break_apart_items',
#      'make_fire_pit',
#      'light_fire',
#      'cauldron_fetch_water',
#      'brew_potion',
#      'upgrade_cauldron',
#      'broken_bridge',
#      'fuse_enchantments',
#      'make_planks',
#      'fix_bridge',
#      'cross_bridge',
#      'temple',
#      'automate',
#      'make_bowl',
#      'mutate',
#      'fetch_water',
#      'prepare_paint',
#      'make_paintbrush',
#      'upgrade_ouroboros',
#      'upgrade_star_stone',
#      'fetch_water_yellow',
#      'prepare_paint_yellow',
#      'craft_fishing_rod',
#      'craft_goal_book',
#      'craft_grappling_hook_lv2',
#      'mushroom_shop',
#      'uulaa_shop'],
#     'has_played': ['find_shelter',
#      'build_door',
#      'deadwood_valley',
#      'build_workstation',
#      'craft_hatchet',
#      'craft_shovel',
#      'prospect_cliff',
#      'clean_sword',
#      'upgrade_workstation_2',
#      'craft_canoe',
#      'dig_cave',
#      'caustic_caves',
#      'craft_anvil_hammer',
#      'craft_anvil',
#      'anvil',
#      'cross_deadwood_river',
#      'bronze_gate',
#      'upgrade_workstation_3',
#      'utility_belt',
#      'craft_grappling_hook',
#      'waterfall',
#      'fungus_forest',
#      'fungus_forest_boss',
#      'undead_crypt_intro',
#      'undead_crypt',
#      'undead_crypt_boss',
#      'fungus_forest_boss_hard',
#      'bronze_mine',
#      'upgrade_workstation_4',
#      'bronze_guardian',
#      'make_cauldron',
#      'make_fire_pit',
#      'light_fire',
#      'cauldron_fetch_water',
#      'brew_potion',
#      'break_apart_items',
#      'icy_ridge',
#      'upgrade_cauldron',
#      'bronze_guardian_hard',
#      'broken_bridge',
#      'make_planks',
#      'fix_bridge',
#      'fuse_enchantments',
#      'cross_bridge',
#      'temple',
#      'nagaraja',
#      'automate',
#      'rocky_plateau',
#      'undead_crypt_boss_hard',
#      'fungus_forest_boss_harder',
#      'nagaraja_hard',
#      'undead_crypt_boss_harder',
#      'bronze_guardian_harder',
#      'make_bowl',
#      'fetch_water',
#      'prepare_paint',
#      'make_paintbrush',
#      'upgrade_ouroboros',
#      'mutate',
#      'upgrade_star_stone',
#      'nagaraja_harder',
#      'fetch_water_yellow',
#      'prepare_paint_yellow',
#      'croaked_deadwood_valley',
#      'croaked_rocky_plateau',
#      'roof_overhead_valley',
#      'roof_overhead_hovel',
#      'roof_overhead_normal_caves',
#      'roof_overhead_normal_mine',
#      'bad_business_shop',
#      'throwing_stones_river_crossing',
#      'craft_fishing_rod',
#      'throwing_stones_falls',
#      'wildride_undead_crypt_intro',
#      'wildride_undead_crypt_gate',
#      'wildride_undead_crypt_halls',
#      'wildride_Pallas',
#      'remnants_five_shop',
#      'remnants_five_uulaa',
#      'uulaa_shop_rem5',
#      'titanic_accord_undead_crypt_gate',
#      'titanic_accord_Pallas',
#      'stream_of_the_silent',
#      'charlatan_meeting',
#      'craft_goal_book',
#      'initiate_caves',
#      'initiate_valley',
#      'initiate_hovel',
#      'initiate_temple_entrance',
#      'initiate_temple_hall',
#      'initiate_nagaraja',
#      'uulaa_shop_bs',
#      'dug_location',
#      'sly_location',
#      'vie_location',
#      'tux_location',
#      'head_heels_factory',
#      'head_heels_gate',
#      'head_heels_falls',
#      'craft_grappling_hook_lv2',
#      'hans_shop',
#      'mushroom_shop',
#      'uulaa_shop'],
#     'has_completed': ['rocky_plateau',
#      'find_shelter',
#      'build_door',
#      'deadwood_valley',
#      'build_workstation',
#      'craft_hatchet',
#      'craft_shovel',
#      'prospect_cliff',
#      'clean_sword',
#      'upgrade_workstation_2',
#      'dig_cave',
#      'deadwood_valley1',
#      'rocky_plateau1',
#      'craft_anvil_hammer',
#      'craft_anvil',
#      'rocky_plateau2',
#      'caustic_caves1',
#      'caustic_caves2',
#      'deadwood_valley2',
#      'craft_canoe',
#      'caustic_caves3',
#      'upgrade_workstation_3',
#      'utility_belt',
#      'craft_grappling_hook',
#      'deadwood_valley3',
#      'waterfall',
#      'fungus_forest',
#      'fungus_forest1',
#      'fungus_forest2',
#      'deadwood_valley4',
#      'fungus_forest3',
#      'undead_crypt_intro',
#      'caustic_caves4',
#      'undead_crypt',
#      'undead_crypt1',
#      'undead_crypt2',
#      'deadwood_valley5',
#      'undead_crypt3',
#      'bronze_mine',
#      'upgrade_workstation_4',
#      'bronze_mine1',
#      'bronze_mine2',
#      'bronze_mine3',
#      'make_cauldron',
#      'make_fire_pit',
#      'light_fire',
#      'cauldron_fetch_water',
#      'icy_ridge',
#      'icy_ridge1',
#      'upgrade_cauldron',
#      'icy_ridge2',
#      'caustic_caves5',
#      'bronze_mine4',
#      'icy_ridge3',
#      'make_planks',
#      'fix_bridge',
#      'temple',
#      'temple1',
#      'fungus_forest4',
#      'temple2',
#      'temple3',
#      'rocky_plateau3',
#      'undead_crypt4',
#      'fungus_forest5',
#      'rocky_plateau4',
#      'temple4',
#      'undead_crypt5',
#      'rocky_plateau5',
#      'make_bowl',
#      'fetch_water',
#      'prepare_paint',
#      'make_paintbrush',
#      'undead_crypt6',
#      'deadwood_valley6',
#      'bronze_mine5',
#      'fungus_forest6',
#      'fungus_forest7',
#      'fungus_forest8',
#      'temple5',
#      'bronze_mine6',
#      'bronze_mine7',
#      'bronze_mine8',
#      'undead_crypt7',
#      'icy_ridge4',
#      'icy_ridge5',
#      'fungus_forest9',
#      'caustic_caves6',
#      'caustic_caves7',
#      'caustic_caves8',
#      'deadwood_valley7',
#      'deadwood_valley8',
#      'deadwood_valley9',
#      'deadwood_valley10',
#      'fetch_water_yellow',
#      'prepare_paint_yellow',
#      'caustic_caves9',
#      'caustic_caves10',
#      'caustic_caves11',
#      'caustic_caves12',
#      'temple6',
#      'temple7',
#      'temple8',
#      'undead_crypt8',
#      'temple9',
#      'temple10',
#      'temple11',
#      'undead_crypt9',
#      'undead_crypt10',
#      'fungus_forest10',
#      'fungus_forest11',
#      'fungus_forest12',
#      'fungus_forest13',
#      'fungus_forest14',
#      'fungus_forest15',
#      'caustic_caves13',
#      'temple12',
#      'temple13',
#      'temple14',
#      'bronze_mine9',
#      'bronze_mine10',
#      'temple15',
#      'deadwood_valley11',
#      'deadwood_valley12',
#      'deadwood_valley13',
#      'deadwood_valley14',
#      'deadwood_valley15',
#      'undead_crypt11',
#      'undead_crypt12',
#      'undead_crypt13',
#      'bronze_mine11',
#      'bronze_mine12',
#      'icy_ridge6',
#      'undead_crypt14',
#      'icy_ridge7',
#      'icy_ridge8',
#      'icy_ridge9',
#      'icy_ridge10',
#      'caustic_caves14',
#      'caustic_caves15',
#      'rocky_plateau6',
#      'bronze_mine13',
#      'bronze_mine14',
#      'icy_ridge11',
#      'icy_ridge12',
#      'icy_ridge13',
#      'icy_ridge14',
#      'icy_ridge15',
#      'rocky_plateau7',
#      'rocky_plateau8',
#      'undead_crypt15',
#      'rocky_plateau9',
#      'rocky_plateau10',
#      'croaked_rocky_plateau',
#      'craft_fishing_rod',
#      'rocky_plateau11',
#      'rocky_plateau12',
#      'rocky_plateau13',
#      'rocky_plateau14',
#      'bronze_mine15',
#      'rocky_plateau15',
#      'craft_goal_book',
#      'craft_grappling_hook_lv2'],
#     'stats': [{'id': 'caustic_caves3',
#       'bT': 899,
#       'aT': '1232.743',
#       'aHl': '0.113327',
#       'aHg': '0.0007247925',
#       'aKg': 22,
#       'aRg': '19.85553',
#       'd': '468.4879'},
#      {'id': 'caustic_caves',
#       'lpDiff': 15,
#       'bT': 0,
#       'aT': 0,
#       'aHl': 0,
#       'aHg': 0,
#       'aKg': 0},
#      {'id': 'fungus_forest3',
#       'bT': 1055,
#       'aT': '1970.91',
#       'aHl': '8.940109',
#       'aHg': '0.8922577',
#       'aKg': '27.41939',
#       'aRg': '31.10681',
#       'd': '1590.956'},
#      {'id': 'caustic_caves4',
#       'bT': 1044,
#       'aT': '1424.313',
#       'aHl': '0.6157074',
#       'aHg': '0.3170471',
#       'aKg': '31.30135',
#       'aRg': '17.50592'},
#      {'id': 'fungus_forest',
#       'lpDiff': 15,
#       'bT': 0,
#       'aT': 0,
#       'aHl': 0,
#       'aHg': 0,
#       'aKg': 0},
#      {'id': 'undead_crypt3',
#       'bT': 1370,
#       'aT': '3066.769',
#       'aHl': '12.4149',
#       'aHg': '2.637535',
#       'aKg': '34.45981',
#       'aRg': '0.0273819',
#       'd': '1115.28'},
#      {'id': 'bronze_mine3',
#       'bT': 1595,
#       'aT': '5525.639',
#       'aHl': '47.32849',
#       'aHg': '1.053001',
#       'aKg': '54.8275',
#       'aRg': '83.013'},
#      {'id': 'undead_crypt',
#       'lpDiff': 15,
#       'bT': 0,
#       'aT': 0,
#       'aHl': 0,
#       'aHg': 0,
#       'aKg': 0},
#      {'id': 'bronze_mine',
#       'lpDiff': 15,
#       'bT': 0,
#       'aT': 0,
#       'aHl': 0,
#       'aHg': 0,
#       'aKg': 0},
#      {'id': 'caustic_caves5',
#       'bT': 835,
#       'aT': '1764.399',
#       'aHl': '25.1049',
#       'aHg': '1.869362',
#       'aKg': '34.47314',
#       'aRg': '12.074',
#       'd': '648.2919'},
#      {'id': 'bronze_mine4',
#       'bT': 2677,
#       'aT': '3809.816',
#       'aHl': '29.14302',
#       'aHg': '1.601822',
#       'aKg': '30.55231',
#       'aRg': 16},
#      {'id': 'icy_ridge3',
#       'bT': 1162,
#       'aT': '3813.592',
#       'aHl': '25.026',
#       'aHg': '2.521996',
#       'aKg': '27.4365',
#       'aRg': '6.596001'},
#      {'id': 'fungus_forest4',
#       'bT': 2886,
#       'aT': '2896.14',
#       'aHl': '29.87',
#       'aHg': '0.1499939',
#       'aKg': '32.97',
#       'aRg': '0.9700012'},
#      {'id': 'temple3',
#       'bT': 1483,
#       'aT': '5890.438',
#       'aHl': '31.34492',
#       'aHg': '0.8468094',
#       'aKg': '37.48015',
#       'aRg': '0.8468094',
#       'd': '3716.08'},
#      {'id': 'rocky_plateau3',
#       'bT': 3691,
#       'aT': '5246.5',
#       'aHl': '40.25',
#       'aHg': 0,
#       'aKg': 0,
#       'aRg': 22},
#      {'id': 'undead_crypt4',
#       'bT': 2896,
#       'aT': '5024.18',
#       'aHl': '30.55',
#       'aHg': '0.3600006',
#       'aKg': 43,
#       'aRg': 1},
#      {'id': 'icy_ridge',
#       'lpDiff': 15,
#       'bT': 0,
#       'aT': 0,
#       'aHl': 0,
#       'aHg': 0,
#       'aKg': 0},
#      {'id': 'fungus_forest5',
#       'bT': 3320,
#       'aT': 3646,
#       'aHl': 9,
#       'aHg': 0,
#       'aKg': 49},
#      {'id': 'rocky_plateau4',
#       'bT': 3149,
#       'aT': '3753.35',
#       'aHl': '64.14999',
#       'aHg': '0.1500015',
#       'aKg': '182.75',
#       'aRg': '10.35'},
#      {'id': 'temple',
#       'lpDiff': 15,
#       'bT': 0,
#       'aT': 0,
#       'aHl': 0,
#       'aHg': 0,
#       'aKg': 0},
#      {'id': 'temple4',
#       'bT': 4842,
#       'aT': '6272.75',
#       'aHl': '32.36',
#       'aHg': '0.2099991',
#       'aKg': 36},
#      {'id': 'undead_crypt5',
#       'bT': 3836,
#       'aT': '6331.81',
#       'aHl': '29.03',
#       'aHg': '43.16',
#       'aKg': 55},
#      {'id': 'rocky_plateau5',
#       'bT': 1520,
#       'aT': '2795.322',
#       'aHl': '6.420509',
#       'aHg': '4.73436',
#       'aKg': '17.65763',
#       'aRg': '5.381508',
#       'd': 5043},
#      {'id': 'rocky_plateau',
#       'lpDiff': 15,
#       'bT': 0,
#       'aT': 0,
#       'aHl': 0,
#       'aHg': 0,
#       'aKg': 0},
#      {'id': 'undead_crypt6',
#       'bT': 1914,
#       'aT': 3874,
#       'aHl': 5,
#       'aHg': 22,
#       'aKg': 34},
#      {'id': 'bronze_mine5',
#       'bT': 1463,
#       'aT': '2491.031',
#       'aHl': '9.709663',
#       'aHg': '6.269173',
#       'aKg': '34.60255',
#       'aRg': '15.06867',
#       'd': 1357},
#      {'id': 'fungus_forest6',
#       'bT': 2153,
#       'aT': 2767,
#       'aHl': 12,
#       'aHg': 7,
#       'aKg': 43},
#      {'id': 'fungus_forest7',
#       'bT': 2983,
#       'aT': 3658,
#       'aHl': 38,
#       'aHg': 2,
#       'aKg': 37},
#      {'id': 'fungus_forest8',
#       'bT': 2160,
#       'aT': 3418,
#       'aHl': 22,
#       'aHg': 6,
#       'aKg': 48},
#      {'id': 'temple5',
#       'bT': 4754,
#       'aT': 8755,
#       'aHl': 40,
#       'aHg': 32,
#       'aKg': 79,
#       'aRg': 6},
#      {'id': 'bronze_mine6',
#       'bT': 2545,
#       'aT': 3440,
#       'aHl': 1,
#       'aHg': 1,
#       'aKg': 31,
#       'aRg': 15},
#      {'id': 'bronze_mine7',
#       'bT': 2672,
#       'aT': 3210,
#       'aHl': 27,
#       'aHg': 1,
#       'aKg': 30,
#       'aRg': 17},
#      {'id': 'bronze_mine8',
#       'bT': 4133,
#       'aT': 4216,
#       'aHl': 44,
#       'aHg': 1,
#       'aKg': 41,
#       'aRg': 15},
#      {'id': 'undead_crypt7',
#       'bT': 7738,
#       'aT': 7738,
#       'aHl': 119,
#       'aHg': 68,
#       'aKg': 35},
#      {'id': 'icy_ridge4',
#       'bT': 2801,
#       'aT': 3769,
#       'aHl': 66,
#       'aHg': 6,
#       'aKg': 36},
#      {'id': 'icy_ridge5',
#       'bT': 2637,
#       'aT': 3241,
#       'aHl': 30,
#       'aHg': 25,
#       'aKg': 50},
#      {'id': 'fungus_forest9',
#       'bT': 2238,
#       'aT': 4129,
#       'aHl': 30,
#       'aHg': 7,
#       'aKg': 64},
#      {'id': 'caustic_caves6',
#       'bT': 1815,
#       'aT': '3064.69',
#       'aHl': '4.944504',
#       'aHg': '5.645401',
#       'aKg': '35.14819',
#       'aRg': '12.0564',
#       'd': 4810},
#      {'id': 'caustic_caves7',
#       'bT': 2512,
#       'aT': 3068,
#       'aHl': 19,
#       'aHg': 1,
#       'aKg': 38,
#       'aRg': 13},
#      {'id': 'caustic_caves8',
#       'bT': 2902,
#       'aT': 3185,
#       'aHl': 8,
#       'aHg': 5,
#       'aKg': 38,
#       'aRg': 12},
#      {'id': 'caustic_caves9',
#       'bT': 2605,
#       'aT': 3055,
#       'aHl': 37,
#       'aHg': 4,
#       'aKg': 37,
#       'aRg': 10},
#      {'id': 'caustic_caves10',
#       'bT': 1654,
#       'aT': '3864.169',
#       'aHl': '4.131882',
#       'aHg': '0.212471',
#       'aKg': '39.496',
#       'aRg': '11.52898',
#       'd': '7391.855'},
#      {'id': 'caustic_caves11',
#       'bT': 2035,
#       'aT': '3268.452',
#       'aHl': '30.74899',
#       'aHg': '4.432899',
#       'aKg': '28.1773',
#       'aRg': '11.9718'},
#      {'id': 'caustic_caves12',
#       'bT': 1606,
#       'aT': '3330.68',
#       'aHl': '11.4945',
#       'aHg': '11.4945',
#       'aKg': '37.67151',
#       'aRg': '14.5122',
#       'd': '13785.06'},
#      {'id': 'temple6',
#       'bT': 12859,
#       'aT': 12859,
#       'aHl': 47,
#       'aHg': 60,
#       'aKg': 140},
#      {'id': 'temple7',
#       'bT': 12813,
#       'aT': 12813,
#       'aHl': 55,
#       'aHg': 58,
#       'aKg': 137},
#      {'id': 'temple8',
#       'bT': 8106,
#       'aT': 9950,
#       'aHl': 49,
#       'aHg': 59,
#       'aKg': 132},
#      {'id': 'undead_crypt8',
#       'bT': 6338,
#       'aT': 6338,
#       'aHl': 117,
#       'aHg': 47,
#       'aKg': 34},
#      {'id': 'temple9',
#       'bT': 5706,
#       'aT': 6427,
#       'aHl': 48,
#       'aHg': 12,
#       'aKg': 143},
#      {'id': 'temple10',
#       'bT': 6529,
#       'aT': 8647,
#       'aHl': 55,
#       'aHg': 19,
#       'aKg': 146,
#       'aRg': 7},
#      {'id': 'temple11',
#       'bT': 6461,
#       'aT': 6461,
#       'aHl': 89,
#       'aHg': 3,
#       'aKg': 98},
#      {'id': 'undead_crypt9',
#       'bT': 3120,
#       'aT': 4447,
#       'aHl': 23,
#       'aHg': 41,
#       'aKg': 49},
#      {'id': 'undead_crypt10',
#       'bT': 2424,
#       'aT': 3669,
#       'aHl': 37,
#       'aHg': 44,
#       'aKg': 53},
#      {'id': 'fungus_forest10',
#       'bT': 3815,
#       'aT': 3815,
#       'aHl': 26,
#       'aHg': 2,
#       'aKg': 81},
#      {'id': 'fungus_forest11',
#       'bT': 2437,
#       'aT': '3235.31',
#       'aHl': '11.64',
#       'aHg': 0,
#       'aKg': 33},
#      {'id': 'fungus_forest12',
#       'bT': 3303,
#       'aT': 3303,
#       'aHl': 14,
#       'aHg': 0,
#       'aKg': 28},
#      {'id': 'fungus_forest13',
#       'bT': 3276,
#       'aT': 3673,
#       'aHl': 38,
#       'aHg': 0,
#       'aKg': 35},
#      {'id': 'fungus_forest14',
#       'bT': 1951,
#       'aT': '2084.953',
#       'aHl': '0.1082153',
#       'aHg': '0.003044128',
#       'aKg': '47.58876',
#       'd': '18320.83'},
#      {'id': 'fungus_forest15',
#       'bT': 1885,
#       'aT': '2038.508',
#       'aHl': 0,
#       'aHg': 0,
#       'aKg': '58.93935',
#       'd': '23341.28'},
#      {'id': 'caustic_caves13',
#       'bT': 4069,
#       'aT': 4457,
#       'aHl': 58,
#       'aHg': 9,
#       'aKg': 40,
#       'aRg': 17},
#      {'id': 'temple12',
#       'bT': 6905,
#       'aT': 7425,
#       'aHl': 104,
#       'aHg': 15,
#       'aKg': 146},
#      {'id': 'temple13',
#       'bT': 7516,
#       'aT': 7538,
#       'aHl': 124,
#       'aHg': 19,
#       'aKg': 149},
#      {'id': 'temple14',
#       'bT': 3317,
#       'aT': '3440.377',
#       'aHl': '0.1502304',
#       'aHg': '0.0514679',
#       'aKg': '155.7012',
#       'aRg': '0.00894928',
#       'd': '39331.34'},
#      {'id': 'bronze_mine9',
#       'bT': 3091,
#       'aT': 3713,
#       'aHl': 6,
#       'aHg': 3,
#       'aKg': 64,
#       'aRg': 15},
#      {'id': 'bronze_mine10',
#       'bT': 3741,
#       'aT': 4153,
#       'aHl': 88,
#       'aHg': 4,
#       'aKg': 84,
#       'aRg': 14},
#      {'id': 'temple15',
#       'bT': 3120,
#       'aT': '3265.714',
#       'aHl': 0,
#       'aHg': 0,
#       'aKg': '168.496',
#       'aRg': '0.007461548',
#       'd': '41451.17'},
#      {'id': 'undead_crypt11',
#       'bT': 2633,
#       'aT': '3945.74',
#       'aHl': '36.7007',
#       'aHg': '26.6844',
#       'aKg': '36.82269',
#       'd': 13219},
#      {'id': 'undead_crypt12',
#       'bT': 3781,
#       'aT': 3781,
#       'aHl': 51,
#       'aHg': 25,
#       'aKg': 34},
#      {'id': 'undead_crypt13',
#       'bT': 4744,
#       'aT': 4744,
#       'aHl': 115,
#       'aHg': 68,
#       'aKg': 41},
#      {'id': 'bronze_mine11',
#       'bT': 1922,
#       'aT': '2963.587',
#       'aHl': '45.3475',
#       'aHg': '1.649002',
#       'aKg': '23.7275',
#       'aRg': '11.002'},
#      {'id': 'bronze_mine12',
#       'bT': 3861,
#       'aT': 4764,
#       'aHl': 70,
#       'aHg': 3,
#       'aKg': 40,
#       'aRg': 13},
#      {'id': 'icy_ridge6',
#       'bT': 1114,
#       'aT': '3719.42',
#       'aHl': '64.98999',
#       'aHg': '1.940002',
#       'aKg': '35.88',
#       'd': 9792},
#      {'id': 'undead_crypt14',
#       'bT': 2200,
#       'aT': '2515.845',
#       'aHl': '13.60212',
#       'aHg': '44.52637',
#       'aKg': '54.15649',
#       'd': '32650.5'},
#      {'id': 'icy_ridge7',
#       'bT': 3234,
#       'aT': 3234,
#       'aHl': 41,
#       'aHg': 0,
#       'aKg': 48},
#      {'id': 'icy_ridge8',
#       'bT': 3536,
#       'aT': 3536,
#       'aHl': 72,
#       'aHg': 1,
#       'aKg': 46},
#      {'id': 'icy_ridge9',
#       'bT': 2373,
#       'aT': 3185,
#       'aHl': 48,
#       'aHg': 18,
#       'aKg': 54},
#      {'id': 'icy_ridge10',
#       'bT': 3439,
#       'aT': 3906,
#       'aHl': 104,
#       'aHg': 3,
#       'aKg': 60},
#      {'id': 'caustic_caves14',
#       'bT': 1856,
#       'aT': '2785.344',
#       'aHl': '4.433372',
#       'aHg': '0.05826569',
#       'aKg': '36.81129',
#       'aRg': '16.62399',
#       'd': '15336.54'},
#      {'id': 'caustic_caves15',
#       'bT': 1793,
#       'aT': '1950.946',
#       'aHl': 0,
#       'aHg': 0,
#       'aKg': '51.45929',
#       'aRg': '16.17073',
#       'd': '19237.7'},
#      {'id': 'rocky_plateau6',
#       'bT': 3674,
#       'aT': '7905.14',
#       'aHl': '202.73',
#       'aHg': '110.79',
#       'aKg': 20,
#       'aRg': '66.92999'},
#      {'id': 'bronze_mine13',
#       'bT': 3585,
#       'aT': 3585,
#       'aHl': 7,
#       'aHg': 4,
#       'aKg': 56,
#       'aRg': 16},
#      {'id': 'bronze_mine14',
#       'bT': 2253,
#       'aT': '2953.222',
#       'aHl': '7.629395E-06',
#       'aHg': '48.34464',
#       'aKg': '67.59604',
#       'aRg': '15.64622',
#       'd': '24260.68'},
#      {'id': 'icy_ridge11',
#       'bT': 2992,
#       'aT': 3692,
#       'aHl': 90,
#       'aHg': 11,
#       'aKg': 45},
#      {'id': 'icy_ridge12',
#       'bT': 2922,
#       'aT': 2922,
#       'aHl': 50,
#       'aHg': 3,
#       'aKg': 50},
#      {'id': 'icy_ridge13',
#       'bT': 2852,
#       'aT': 2852,
#       'aHl': 88,
#       'aHg': 2,
#       'aKg': 50},
#      {'id': 'icy_ridge14',
#       'bT': 1428,
#       'aT': '2799.09',
#       'aHl': '90.37344',
#       'aHg': '15.19554',
#       'aKg': '59.93396'},
#      {'id': 'icy_ridge15',
#       'bT': 1355,
#       'aT': '1485.372',
#       'aHl': '0.09088898',
#       'aHg': '0.08975983',
#       'aKg': '57.90538',
#       'd': '21659.51',
#       'Dd': '0.9700012',
#       'DF': 1},
#      {'id': 'rocky_plateau7',
#       'bT': 5329,
#       'aT': 5329,
#       'aHl': 51,
#       'aHg': 7,
#       'aKg': 20,
#       'aRg': 1},
#      {'id': 'rocky_plateau8',
#       'bT': 6077,
#       'aT': 6077,
#       'aHl': 117,
#       'aHg': 16,
#       'aKg': 20},
#      {'id': 'undead_crypt15',
#       'bT': 1895,
#       'aT': '2343.387',
#       'aHl': '5.143219',
#       'aHg': '24.48275',
#       'aKg': '65.80011',
#       'aRg': '0.01478577',
#       'd': '43270.78'},
#      {'id': 'rocky_plateau9',
#       'bT': 8485,
#       'aT': 8485,
#       'aHl': 117,
#       'aHg': 1,
#       'aKg': 20,
#       'aRg': 2},
#      {'id': 'rocky_plateau10',
#       'bT': 3623,
#       'aT': 10037,
#       'aHl': 133,
#       'aHg': 136,
#       'aKg': 20,
#       'aRg': 2},
#      {'id': 'rocky_plateau11',
#       'bT': 3895,
#       'aT': 4215,
#       'aHl': 15,
#       'aHg': 13,
#       'aKg': 25,
#       'aRg': 10},
#      {'id': 'rocky_plateau12',
#       'bT': 3677,
#       'aT': 4052,
#       'aHl': 9,
#       'aHg': 15,
#       'aKg': 25,
#       'aRg': 7},
#      {'id': 'rocky_plateau13',
#       'bT': 4324,
#       'aT': 6089,
#       'aHl': 95,
#       'aHg': 99,
#       'aKg': 25,
#       'aRg': 8},
#      {'id': 'rocky_plateau14',
#       'bT': 2600,
#       'aT': '5076.091',
#       'aHl': '74.70233',
#       'aHg': '71.94254',
#       'aKg': 25,
#       'aRg': '11.87335'},
#      {'id': 'bronze_mine15',
#       'bT': 1996,
#       'aT': '2251.48',
#       'aHl': 0,
#       'aHg': 0,
#       'aKg': '81.46625',
#       'aRg': '15.63376',
#       'd': 43813},
#      {'id': 'rocky_plateau15',
#       'bT': 2172,
#       'aT': '2217.988',
#       'aHl': 0,
#       'aHg': 0,
#       'aKg': '25.00001',
#       'aRg': '9.17485'},
#      {'id': 'deadwood_valley',
#       'lpDiff': 15,
#       'bT': 0,
#       'aT': 0,
#       'aHl': 0,
#       'aHg': 0,
#       'aKg': 0},
#      {'id': 'deadwood_valley15',
#       'bT': 1282,
#       'aT': '1311.189',
#       'aHl': '0.02720642',
#       'aHg': '0.03024292',
#       'aKg': '21.67978',
#       'aRg': '27.61755',
#       'd': '16593.84'},
#      {'id': 'deadwood_valley3',
#       'bT': 910,
#       'aT': '991.6273',
#       'aHl': '1.661713',
#       'aHg': '0.08729553',
#       'aKg': '15.56454',
#       'aRg': '29.62376',
#       'd': 632},
#      {'id': 'deadwood_valley4',
#       'bT': 917,
#       'aT': '935.63',
#       'aHl': '0.2400055',
#       'aHg': '0.05999756',
#       'aKg': 26,
#       'aRg': '25.3'},
#      {'id': 'deadwood_valley5',
#       'bT': 907,
#       'aT': '960.3201',
#       'aHl': '0.6900024',
#       'aHg': '0.08999634',
#       'aKg': 33,
#       'aRg': 26},
#      {'id': 'deadwood_valley6',
#       'bT': 1197,
#       'aT': 1197,
#       'aHl': 0,
#       'aHg': 0,
#       'aKg': 9,
#       'aRg': 25},
#      {'id': 'deadwood_valley7',
#       'bT': 1211,
#       'aT': 1211,
#       'aHl': 0,
#       'aHg': 0,
#       'aKg': 3,
#       'aRg': 25},
#      {'id': 'deadwood_valley11',
#       'bT': 1244,
#       'aT': '1569.961',
#       'aHl': '13.7934',
#       'aHg': '2.298897',
#       'aKg': '13.4674',
#       'aRg': '27.2337',
#       'd': '9883.97'},
#      {'id': 'deadwood_valley14',
#       'bT': 1309,
#       'aT': '1316.369',
#       'aHl': 0,
#       'aHg': 0,
#       'aKg': '17.3468',
#       'aRg': '27.05733',
#       'd': '15221.26'}],
#     'lastRewardTime': '05/09/2024 14:24:54',
#     'skullnata': '05/09/2024 10:24:37'},
#    'inventory_data': {'Stone': 5453641,
#     'Wood': 58760,
#     'Tar': 6670249,
#     'Xi': 7979530,
#     'Bronze': 101364,
#     'itms': [{'id': 'moonbloom_bud',
#       'co': 4,
#       'da': {'hI': 'True', 'rng': '-1'}},
#      {'id': 'moonbloom_petal', 'co': 28, 'da': {'hI': 'True', 'rng': '-1'}},
#      {'id': 'event_ticket', 'co': 436, 'da': {'hI': 'True', 'rng': '-1'}},
#      {'id': 'ki_crystal', 'co': 2026, 'da': {'hI': 'True', 'rng': '-1'}},
#      {'id': 'resonant_clay', 'co': 2, 'da': {'hI': 'True', 'rng': 0}},
#      {'id': 'crystal_powder', 'co': 229, 'da': {'hI': 'True', 'rng': '-1'}},
#      {'id': 'shiny', 'co': 7, 'da': {'hI': 'True', 'rng': '-1'}},
#      {'id': 'hourglass', 'co': 3, 'da': {'hI': 'True', 'rng': 0}},
#      {'id': 'name_tag', 'co': 32, 'da': {'hI': 'True', 'rng': '-1'}},
#      {'id': 'bashing_shield',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 135446},
#        'rng': 0,
#        'lC': 32,
#        'lBU': 8,
#        'tag': 'B8SH'}},
#      {'id': 'fire_talisman',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Fire',
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 992189},
#        'rng': 0,
#        'lC': 32,
#        'lBU': 8,
#        'tag': 'F8RE',
#        'sig': 'BlowItUp'}},
#      {'id': 'blade_of_god',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 921934},
#        'rng': '-1',
#        'lC': 32,
#        'lBU': 8,
#        'tag': 'BOG'}},
#      {'id': 'compound_shield',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 99048},
#        'rng': 93354,
#        'tag': 'F8ST'}},
#      {'id': 'cult_mask',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 928852},
#        'rng': '-1',
#        'lC': 32,
#        'lBU': 8,
#        'tag': 'M8SK'}},
#      {'id': 'skeleton_arm',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 925704},
#        'rng': '-1',
#        'lC': 32,
#        'lBU': 8,
#        'tag': '8RM'}},
#      {'id': 'aether_talisman',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'el': 'AEther',
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 582627},
#        'rng': 0,
#        'lC': 22,
#        'lBU': 8,
#        'tag': 'A8THER'}},
#      {'id': 'enchantment',
#       'co': 2,
#       'da': {'ra': {'lv': 11, 'ql': 571, 'sSS': 0}, 'rng': '-1'}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 10, 'ql': 271, 'sSS': 0}, 'rng': '-1'}},
#      {'id': 'enchantment',
#       'co': 2,
#       'da': {'ra': {'lv': 9, 'ql': 214, 'sSS': 0}, 'rng': '-1'}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 7, 'ql': 100, 'sSS': 98596}, 'rng': 118967}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 6, 'ql': 43, 'sSS': 0}, 'rng': '-1'}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 5, 'ql': 31, 'sSS': 371824}, 'rng': 412353}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 4, 'ql': 19, 'sSS': 33282}, 'rng': 557910}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 4, 'ql': 19, 'sSS': 443043}, 'rng': 651840}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 4, 'ql': 19, 'sSS': 461336}, 'rng': 601050}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 4, 'ql': 19, 'sSS': 576034}, 'rng': 538425}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 3, 'ql': 7, 'sSS': 762033}, 'rng': 282205}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 2, 'ql': 4, 'sSS': 121437}, 'rng': 393613}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 2, 'ql': 4, 'sSS': 161849}, 'rng': 95425}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 2, 'ql': 4, 'sSS': 303004}, 'rng': 311950}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 2, 'ql': 4, 'sSS': 384375}, 'rng': 158288}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 2, 'ql': 4, 'sSS': 528410}, 'rng': 904527}},
#      {'id': 'enchantment',
#       'da': {'hI': 'True',
#        'ra': {'lv': 2, 'ql': 4, 'sSS': 54577},
#        'rng': 451112}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 2, 'ql': 4, 'sSS': 665048}, 'rng': 821658}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 2, 'ql': 4, 'sSS': 912027}, 'rng': 941266}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 2, 'ql': 4, 'sSS': 939802}, 'rng': 857478}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 2, 'ql': 4, 'sSS': 98090}, 'rng': 954273}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 1, 'ql': 1, 'sSS': 531282}, 'rng': 182263}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 1, 'ql': 1, 'sSS': 544782}, 'rng': 760338}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 1, 'ql': 1, 'sSS': 606825}, 'rng': 0}},
#      {'id': 'enchantment',
#       'da': {'ra': {'lv': 1, 'ql': 1, 'sSS': 869712}, 'rng': 443746}},
#      {'id': 'socketed_crossbow',
#       'da': {'hI': 'True',
#        'lv': 8192,
#        'el': 'Poison',
#        'abs': ['element_damage_crossbow_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 195241},
#        'rng': 0,
#        'sh': 'True',
#        'sig': 'IN22'}},
#      {'id': 'socketed_crossbow',
#       'da': {'hI': 'True',
#        'lv': 8192,
#        'el': 'AEther',
#        'abs': ['element_damage_crossbow', 'insta_kill_ranged_onhit'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 77131},
#        'rng': 312301}},
#      {'id': 'socketed_crossbow',
#       'da': {'hI': 'True',
#        'lv': 8192,
#        'el': 'Ice',
#        'abs': ['element_damage_crossbow_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 361147},
#        'rng': 600484}},
#      {'id': 'socketed_hammer',
#       'da': {'hI': 'True',
#        'lv': 8192,
#        'el': 'Poison',
#        'abs': ['element_damage_hammer', 'damage_debuff_onhit'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 827212},
#        'rng': 583051}},
#      {'id': 'socketed_hammer',
#       'da': {'hI': 'True',
#        'lv': 8192,
#        'el': 'Poison',
#        'abs': ['element_damage_hammer_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 399324},
#        'rng': 0,
#        'sh': 'True',
#        'sig': 'SJ6'}},
#      {'id': 'socketed_hammer',
#       'da': {'hI': 'True',
#        'lv': 8192,
#        'el': 'Vigor',
#        'abs': ['element_armor_onenemy', 'when_attacked_heal'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 47442},
#        'rng': 56485}},
#      {'id': 'socketed_hammer',
#       'da': {'hI': 'True',
#        'lv': 8192,
#        'el': 'Vigor',
#        'abs': ['element_damage_hammer_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 763275},
#        'rng': 0,
#        'sh': 'True',
#        'sig': 'Ham23'}},
#      {'id': 'socketed_hammer',
#       'da': {'hI': 'True',
#        'lv': 8192,
#        'el': 'Fire',
#        'abs': ['element_armor_onenemy', 'dot_onhit'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 809330},
#        'rng': 27,
#        'sh': 'True',
#        'sig': 'TT21'}},
#      {'id': 'socketed_long_sword',
#       'da': {'hI': 'True',
#        'lv': 8192,
#        'el': 'Poison',
#        'abs': ['element_damage_long_sword_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 999387},
#        'rng': 233332}},
#      {'id': 'socketed_long_sword',
#       'da': {'hI': 'True',
#        'lv': 8192,
#        'el': 'AEther',
#        'abs': ['element_damage_long_sword_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 999387},
#        'rng': 217046}},
#      {'id': 'socketed_long_sword',
#       'da': {'hI': 'True',
#        'lv': 8192,
#        'el': 'Fire',
#        'abs': ['element_damage_long_sword', 'dot_onhit'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 538710},
#        'rng': 892435}},
#      {'id': 'socketed_long_sword',
#       'da': {'hI': 'True',
#        'lv': 8192,
#        'el': 'Fire',
#        'abs': ['element_damage_long_sword', 'dot_onhit'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 842870},
#        'rng': 749657}},
#      {'id': 'socketed_long_sword',
#       'da': {'hI': 'True',
#        'lv': 8192,
#        'el': 'Fire',
#        'abs': ['element_damage_long_sword_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 726242},
#        'rng': 0,
#        'sh': 'True',
#        'sig': 'VOIDDREAM'}},
#      {'id': 'repeating_crossbow',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 903469},
#        'rng': 101592}},
#      {'id': 'socketed_long_sword',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 366737},
#        'rng': 231578}},
#      {'id': 'socketed_shield',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Poison',
#        'abs': ['element_armor_onenemy', 'damage_buff_whenhit'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 342844},
#        'rng': 5521}},
#      {'id': 'socketed_shield',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'AEther',
#        'abs': ['element_armor_onenemy', 'insta_kill_whenhit'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 332614},
#        'rng': 985837}},
#      {'id': 'socketed_shield',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Fire',
#        'abs': ['element_armor_onenemy', 'dot_whenhit'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 818887},
#        'rng': 151409}},
#      {'id': 'socketed_shield',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Fire',
#        'abs': ['element_armor_onenemy_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 726242},
#        'rng': 0,
#        'sh': 'True',
#        'sig': 'Winter23'}},
#      {'id': 'socketed_shield',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Fire',
#        'abs': ['element_armor_onenemy_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 732763},
#        'rng': 760782}},
#      {'id': 'socketed_staff',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Poison',
#        'abs': ['element_armor_onenemy_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 726242},
#        'rng': 0,
#        'sh': 'True',
#        'sig': 'B2X24'}},
#      {'id': 'socketed_staff',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Vigor',
#        'abs': ['element_armor_onenemy_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 726242},
#        'rng': 0,
#        'sh': 'True',
#        'sig': 'BIGSHIELD'}},
#      {'id': 'socketed_staff',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Ice',
#        'abs': ['element_damage_staff', 'chill_onhit'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 20147},
#        'rng': 436081}},
#      {'id': 'socketed_sword',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Poison',
#        'abs': ['element_damage_sword', 'damage_debuff_onhit'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 96658},
#        'rng': 340215}},
#      {'id': 'socketed_sword',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Poison',
#        'abs': ['element_damage_sword_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 560510},
#        'rng': 340218}},
#      {'id': 'socketed_sword',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Poison',
#        'abs': ['element_damage_sword_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 726242},
#        'rng': 0,
#        'sh': 'True',
#        'sig': 'HoH24'}},
#      {'id': 'socketed_sword',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Vigor',
#        'abs': ['element_damage_sword', 'chance_to_lifesteal_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 813346},
#        'rng': 442029}},
#      {'id': 'socketed_sword',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Vigor',
#        'abs': ['element_damage_sword', 'chance_to_lifesteal_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 685831},
#        'rng': 909141,
#        'sh': 'True'}},
#      {'id': 'socketed_sword',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Vigor',
#        'abs': ['element_damage_sword_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 271724},
#        'rng': 704886}},
#      {'id': 'socketed_sword',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'AEther',
#        'abs': ['element_damage_sword', 'insta_kill_melee_onhit'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 828060},
#        'rng': 559583}},
#      {'id': 'socketed_sword',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'AEther',
#        'abs': ['element_damage_sword', 'insta_kill_melee_onhit'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 387606},
#        'rng': 749557,
#        'sh': 'True'}},
#      {'id': 'socketed_sword',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'AEther',
#        'abs': ['element_damage_sword_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 350486},
#        'rng': 559592}},
#      {'id': 'socketed_sword',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Fire',
#        'abs': ['element_damage_sword', 'dot_onhit'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 425476},
#        'rng': 664083}},
#      {'id': 'socketed_sword',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Fire',
#        'abs': ['element_damage_sword_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 94382},
#        'rng': 62}},
#      {'id': 'socketed_sword',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Fire',
#        'abs': ['element_damage_sword_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 278804},
#        'rng': 621582,
#        'sh': 'True'}},
#      {'id': 'socketed_sword',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Ice',
#        'abs': ['element_damage_sword', 'chill_onhit'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 156004},
#        'rng': 663185}},
#      {'id': 'socketed_sword',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Ice',
#        'abs': ['element_damage_sword', 'chill_onhit'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 605446},
#        'rng': 663187,
#        'sh': 'True'}},
#      {'id': 'socketed_sword',
#       'da': {'hI': 'True',
#        'lv': 4096,
#        'el': 'Ice',
#        'abs': ['element_damage_sword_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 682652},
#        'rng': 274866}},
#      {'id': 'bardiche',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 353760},
#        'rng': 44414}},
#      {'id': 'bardiche',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 187135},
#        'rng': 952200,
#        'sh': 'True'}},
#      {'id': 'compound_shield',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 435829},
#        'rng': 93354}},
#      {'id': 'compound_shield',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 726242},
#        'rng': 0,
#        'sh': 'True',
#        'sig': 'N2X24'}},
#      {'id': 'dashing_shield',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 473056},
#        'rng': 0,
#        'sh': 'True',
#        'sig': 'WR21'}},
#      {'id': 'heavy_hammer',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 595503},
#        'rng': 696047,
#        'sig': 'HAMMERTIME'}},
#      {'id': 'tower_shield',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 726242},
#        'rng': 0,
#        'sh': 'True',
#        'sig': 'Spring24'}},
#      {'id': 'tower_shield',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 821749},
#        'rng': 10490}},
#      {'id': 'wand',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'el': 'Poison',
#        'abs': ['element_damage_wand_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 726242},
#        'rng': 0,
#        'sh': 'True',
#        'sig': 'HAMMERTIME'}},
#      {'id': 'wand',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'el': 'Vigor',
#        'abs': ['element_damage_wand', 'chance_to_lifesteal'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 990770},
#        'rng': 586557}},
#      {'id': 'wand',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'el': 'Vigor',
#        'abs': ['element_damage_wand', 'chance_to_lifesteal'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 65786},
#        'rng': 234929,
#        'sh': 'True'}},
#      {'id': 'wand',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'el': 'Vigor',
#        'abs': ['element_damage_wand_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 789547},
#        'rng': 234928}},
#      {'id': 'wand',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'el': 'AEther',
#        'abs': ['element_damage_wand_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 642762},
#        'rng': 777320,
#        'c': 'golden'}},
#      {'id': 'wand',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'el': 'Ice',
#        'abs': ['element_damage_wand', 'chill_onhit'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 753272},
#        'rng': 774747}},
#      {'id': 'wand',
#       'da': {'hI': 'True',
#        'lv': 2048,
#        'el': 'Ice',
#        'abs': ['element_damage_wand_2'],
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 117372},
#        'rng': 774748}},
#      {'id': 'quarterstaff',
#       'da': {'hI': 'True',
#        'lv': 1024,
#        'ra': {'lv': 21, 'ql': 12049, 'sSS': 576174},
#        'rng': 284445}},
#      {'id': 'wand',
#       'co': 190,
#       'da': {'hI': 'True',
#        'ra': {'lv': 15, 'ql': 1771, 'sSS': 366737},
#        'rng': 418458}},
#      {'id': 'wand',
#       'co': 40,
#       'da': {'hI': 'True',
#        'ra': {'lv': 15, 'ql': 1771, 'sSS': 355782},
#        'rng': 418458}},
#      {'id': 'wand',
#       'co': 107,
#       'da': {'hI': 'True',
#        'ra': {'lv': 15, 'ql': 1771, 'sSS': 341179},
#        'rng': 418458}},
#      {'id': 'bardiche',
#       'da': {'lv': 2,
#        'ra': {'lv': 14, 'ql': 1471, 'sSS': 474396},
#        'rng': 635855}},
#      {'id': 'shield',
#       'da': {'ra': {'lv': 14, 'ql': 1471, 'sSS': 353823}, 'rng': 263235}},
#      {'id': 'sword',
#       'da': {'ra': {'lv': 14, 'ql': 1471, 'sSS': 116526}, 'rng': 739628}},
#      {'id': 'socketed_crossbow',
#       'da': {'lv': 8,
#        'el': 'Poison',
#        'abs': ['element_damage_crossbow', 'damage_debuff_onhit'],
#        'ra': {'lv': 13, 'ql': 1171, 'sSS': 757970},
#        'rng': 475201}},
#      {'id': 'socketed_staff',
#       'da': {'lv': 4,
#        'el': 'AEther',
#        'abs': ['element_armor_onenemy', 'insta_kill_ranged_onhit'],
#        'ra': {'lv': 13, 'ql': 1171, 'sSS': 645839},
#        'rng': 845581}},
#      {'id': 'crossbow',
#       'da': {'ra': {'lv': 13, 'ql': 1171, 'sSS': 774449}, 'rng': 230456}},
#      {'id': 'socketed_shield',
#       'da': {'lv': 4,
#        'el': 'Fire',
#        'abs': ['element_armor_onenemy', 'dot_whenhit'],
#        'ra': {'lv': 12, 'ql': 871, 'sSS': 583580},
#        'rng': 117963}},
#      {'id': 'socketed_staff',
#       'da': {'lv': 4,
#        'el': 'Fire',
#        'abs': ['element_damage_staff_2'],
#        'ra': {'lv': 12, 'ql': 871, 'sSS': 308706},
#        'rng': 16436}},
#      {'id': 'heavy_crossbow',
#       'da': {'lv': 2,
#        'ra': {'lv': 12, 'ql': 871, 'sSS': 595610},
#        'rng': 750084}},
#      {'id': 'socketed_shield',
#       'da': {'lv': 4,
#        'el': 'AEther',
#        'abs': ['element_armor_onenemy_2'],
#        'ra': {'lv': 11, 'ql': 571, 'sSS': 468080},
#        'rng': 91626}},
#      {'id': 'dashing_shield',
#       'da': {'lv': 2,
#        'ra': {'lv': 11, 'ql': 571, 'sSS': 844625},
#        'rng': 900996}},
#      {'id': 'heavy_crossbow',
#       'da': {'lv': 2,
#        'ra': {'lv': 11, 'ql': 571, 'sSS': 288858},
#        'rng': 860838}},
#      {'id': 'crossbow',
#       'co': 4,
#       'da': {'hI': 'True',
#        'ra': {'lv': 11, 'ql': 571, 'sSS': 0},
#        'rng': 522418}},
#      {'id': 'crossbow',
#       'da': {'ra': {'lv': 11, 'ql': 571, 'sSS': 179969}, 'rng': 527393}},
#      {'id': 'quarterstaff',
#       'co': 2,
#       'da': {'hI': 'True',
#        'ra': {'lv': 11, 'ql': 571, 'sSS': 0},
#        'rng': 207284}},
#      {'id': 'quarterstaff',
#       'da': {'ra': {'lv': 11, 'ql': 571, 'sSS': 825096}, 'rng': 447356}},
#      {'id': 'shield',
#       'da': {'hI': 'True',
#        'ra': {'lv': 11, 'ql': 571, 'sSS': 0},
#        'rng': 10943}},
#      {'id': 'shield',
#       'co': 2,
#       'da': {'ra': {'lv': 11, 'ql': 571, 'sSS': 482243}, 'rng': 616034}},
#      {'id': 'sword',
#       'da': {'ra': {'lv': 11, 'ql': 571, 'sSS': 166818}, 'rng': 107978}},
#      {'id': 'wand',
#       'co': 4,
#       'da': {'hI': 'True',
#        'ra': {'lv': 11, 'ql': 571, 'sSS': 0},
#        'rng': 418458}},
#      {'id': 'quarterstaff',
#       'da': {'hI': 'True',
#        'lv': 2,
#        'ra': {'lv': 10, 'ql': 271, 'sSS': 0},
#        'rng': 120034}},
#      {'id': 'socketed_shield',
#       'da': {'lv': 4,
#        'el': 'Poison',
#        'abs': ['element_armor_onenemy', 'damage_buff_whenhit'],
#        'ra': {'lv': 10, 'ql': 271, 'sSS': 41312},
#        'rng': 873023}},
#      {'id': 'heavy_hammer',
#       'da': {'lv': 2,
#        'ra': {'lv': 10, 'ql': 271, 'sSS': 428471},
#        'rng': 44490}},
#      {'id': 'long_sword',
#       'da': {'lv': 2,
#        'ra': {'lv': 10, 'ql': 271, 'sSS': 123104},
#        'rng': 406478}},
#      {'id': 'wand',
#       'da': {'lv': 2,
#        'el': 'Ice',
#        'abs': ['element_damage_wand', 'chill_onhit'],
#        'ra': {'lv': 10, 'ql': 271, 'sSS': 721552},
#        'rng': 400507}},
#      {'id': 'runestone',
#       'da': {'hI': 'True',
#        'el': 'Ice',
#        'ra': {'lv': 10, 'ql': 271, 'sSS': 784406},
#        'rng': 115341}},
#      {'id': 'runestone',
#       'da': {'hI': 'True',
#        'el': 'Ice',
#        'ra': {'lv': 10, 'ql': 271, 'sSS': 400475},
#        'rng': 73786}},
#      {'id': 'quarterstaff',
#       'co': 2,
#       'da': {'hI': 'True',
#        'ra': {'lv': 10, 'ql': 271, 'sSS': 0},
#        'rng': 40255}},
#      {'id': 'quarterstaff',
#       'da': {'ra': {'lv': 10, 'ql': 271, 'sSS': 554516}, 'rng': 245786}},
#      {'id': 'shield',
#       'co': 2,
#       'da': {'hI': 'True',
#        'ra': {'lv': 10, 'ql': 271, 'sSS': 0},
#        'rng': 803639}},
#      {'id': 'sword',
#       'da': {'ra': {'lv': 10, 'ql': 271, 'sSS': 788490}, 'rng': 344212}},
#      {'id': 'sword',
#       'co': 2,
#       'da': {'ra': {'lv': 10, 'ql': 271, 'sSS': 806530}, 'rng': 992119}},
#      {'id': 'wand',
#       'da': {'hI': 'True',
#        'ra': {'lv': 10, 'ql': 271, 'sSS': 0},
#        'rng': 704606}},
#      {'id': 'socketed_shield',
#       'da': {'lv': 4,
#        'el': 'Ice',
#        'abs': ['element_armor_onenemy_2'],
#        'ra': {'lv': 9, 'ql': 214, 'sSS': 391864},
#        'rng': 937720}},
#      {'id': 'socketed_staff',
#       'da': {'lv': 4,
#        'el': 'Poison',
#        'abs': ['element_armor_onenemy_2'],
#        'ra': {'lv': 9, 'ql': 214, 'sSS': 693082},
#        'rng': 511920}},
#      {'id': 'socketed_staff',
#       'da': {'lv': 4,
#        'el': 'AEther',
# ...
#      'socketed_shield_lv4_Fire,element_armor_onenemy,dot_whenhit',
#      'socketed_staff_lv4_Fire,element_damage_staff_2',
#      'socketed_staff_lv4_Fire,element_damage_staff,dot_whenhit',
#      'socketed_staff_lv4_Vigor,element_armor_onenemy,chance_to_lifesteal',
#      'wand_lv8_AEther,element_damage_wand,insta_kill_ranged_onhit',
#      'wand_lv8_Vigor,element_damage_wand_2',
#      'wand_lv2_Vigor,element_damage_wand,chance_to_lifesteal',
#      'wand_lv8_Vigor,element_damage_wand,chance_to_lifesteal',
#      'socketed_sword_lv4_AEther,element_damage_sword,insta_kill_melee_onhit',
#      'socketed_sword_lv4_Vigor,element_damage_sword,chance_to_lifesteal_2',
#      'socketed_staff_lv4_Poison,element_armor_onenemy,damage_buff_whenhit',
#      'socketed_sword_lv4_Ice,element_damage_sword_2',
#      'socketed_shield_lv4_Ice,element_armor_onenemy_2',
#      'moon_stone_lv1',
#      'ouroboros_stone_lv2',
#      'wand_lv2_Fire,element_damage_wand,dot_onhit',
#      'socketed_staff_lv4_Fire,element_armor_onenemy_2',
#      'socketed_staff_lv4_Fire,element_damage_staff,dot_onhit',
#      'socketed_staff_lv4_Fire,element_armor_onenemy,dot_whenhit',
#      'socketed_staff_lv4_Fire,element_armor_onenemy,dot_onhit',
#      'star_stone_lv2',
#      'socketed_staff_lv4_AEther,element_damage_staff_2',
#      'socketed_shield_lv4_Ice,element_armor_onenemy,chill_onenemy',
#      'socketed_staff_lv4_AEther,element_damage_staff,insta_kill_whenhit',
#      'bashing_shield',
#      'goal_book_lv1',
#      'skeleton_arm',
#      'socketed_sword_lv4_Ice,element_damage_sword,chill_onhit',
#      'wand_lv2_Ice,element_damage_wand,chill_onhit',
#      'socketed_staff_lv4_Vigor,element_damage_staff,chance_to_lifesteal',
#      'socketed_staff_lv4_Vigor,element_damage_staff,when_attacked_heal',
#      'socketed_staff_lv4_Vigor,element_damage_staff_2',
#      'socketed_sword_lv4_Vigor,element_damage_sword_2',
#      'socketed_shield_lv4_AEther,element_armor_onenemy,insta_kill_whenhit',
#      'socketed_staff_lv4_Ice,element_damage_staff_2',
#      'socketed_staff_lv4_Ice,element_damage_staff,chill_onenemy',
#      'socketed_staff_lv4_Ice,element_armor_onenemy_2',
#      'socketed_staff_lv4_Ice,element_armor_onenemy,chill_onhit',
#      'socketed_staff_lv4_AEther,element_armor_onenemy,insta_kill_whenhit',
#      'fire_talisman']},
#    'cosmetics': {'golden': ['fire_talisman:Fire;new']},
#    'treasure_factory': {'uniqueDate': '06/24/2022 10:16:35',
#     'crystalDate': '06/24/2022 18:17:19',
#     'goldDate': '06/29/2023 23:13:43'},
#    'ui_state': {'screen': 'WorkstationScreen',
#     'quest_scroll_y': 29,
#     'workstation_scroll_y': 0,
#     'items_scroll_y': 46},
#    'shop_states': {'ids': ['mushroom_shop', 'uulaa_shop'],
#     'mushroom_shop': {'shopId': 'mushroom_shop',
#      'fullEntries': [{'abb': 'True',
#        'id': 'crossbow',
#        'co': 20,
#        'bC': 10,
#        'cpb': 1,
#        'rng': 177402},
#       {'abb': 'True',
#        'id': 'wand',
#        'co': 20,
#        'bC': 10,
#        'cpb': 1,
#        'rng': 295276},
#       {'abb': 'True',
#        'id': 'shield',
#        'co': 20,
#        'bC': 10,
#        'cpb': 1,
#        'rng': 723138},
#       {'abb': 'True',
#        'id': 'sword',
#        'co': 20,
#        'bC': 10,
#        'cpb': 1,
#        'rng': 393786},
#       {'abb': 'True',
#        'id': 'socketed_shield',
#        'co': 10,
#        'bC': 20,
#        'cpb': 2,
#        'rng': 363779},
#       {'abb': 'True',
#        'id': 'runestone',
#        'co': 10,
#        'bC': 30,
#        'cpb': 2,
#        'el': 'Poison',
#        'rng': 392842},
#       {'abb': 'True',
#        'id': 'treasure_1',
#        'co': 1,
#        'bC': 200,
#        'ti': 'tid_treasure_G',
#        'tr': ['giant'],
#        'iSS': 'True'},
#       {'abb': 'True',
#        'id': 'treasure_2',
#        'co': 1,
#        'bC': 1000,
#        'ti': 'tid_treasure_O',
#        'tr': ['rare'],
#        'iSS': 'True'},
#       {'abb': 'True',
#        'id': 'treasure_3',
#        'co': 1,
#        'bC': 4000,
#        'ti': 'tid_treasure_D',
#        'tr': ['epic'],
#        'iSS': 'True'}],
#      'dateFirstOpened': '05/16/2022 21:56:44',
#      'dateGenerated': '08/03/2023 17:07:56',
#      'totalDaysOpen': 3},
#     'uulaa_shop': {'shopId': 'uulaa_shop',
#      'fullEntries': [{'abb': 'True',
#        'id': 'ki_crystal',
#        'co': 1,
#        'ti': 'Daily Crystal',
#        'ic': 'Relics/KiCrystal/ki_crystal_icon_0',
#        'amP': 1},
#       {'abb': 'True',
#        'id': 'lost_treasure',
#        'co': '-1',
#        'bC': 18,
#        'ti': 'Lost Treasure',
#        'tr': ['lost']},
#       {'abb': 'True',
#        'id': 'bashing_shield',
#        'co': '-1',
#        'bC': 21,
#        'sMin': 6,
#        'sMax': 16},
#       {'abb': 'True',
#        'id': 'treasure_gold',
#        'co': '-1',
#        'bC': 16,
#        'ti': 'tid_treasure_GLD',
#        'tr': ['treasure_gold'],
#        'sMin': 4,
#        'sMax': 8,
#        'rng': 883982}],
#      'dateFirstOpened': '05/17/2022 11:49:24',
#      'dateGenerated': '08/02/2023 22:10:53',
#      'totalDaysOpen': 3},
#     'hasSeenShopkeeper': 'True',
#     'totalPurchases': 65,
#     'bundles': {'completed': []}},
#    'crypt_intro': {'timesPlayed': 4,
#     'nextTreasureAvailableDate': '05/18/2022 09:31:41'},
#    'xp': {'currentLevel': 13, 'currentXP': 410},
#    'ouroboros': {'hasBeenTapped': 'True'},
#    'utility_belt': {'loadouts': [{'index': 1},
#      {'index': 2},
#      {'index': 3},
#      {'index': 0},
#      {'index': 9},
#      {'index': 8},
#      {'index': 7},
#      {'index': 6},
#      {'index': 5},
#      {'index': 4}],
#     'sel': 0},
#    'craft_book': {'discovered_crafts': ['sword_sword_sword',
#      'crossbow_crossbow_crossbow',
#      'shield_wand_socketed_shield',
#      'runestone_e_socketed_shield_socketed_shield_e',
#      'shield_shield_shield',
#      'runestone_e_wand_wand_e',
#      'hammer_hammer_hammer',
#      'enchantment_sword_sword',
#      'shield_sword_hammer',
#      'quarterstaff_shield_bardiche',
#      'bardiche_enchantment_bardiche',
#      'sword_wand_socketed_sword',
#      'runestone_e_socketed_sword_socketed_sword_e',
#      'socketed_sword_e_socketed_sword_e_socketed_sword_e',
#      'bardiche_bardiche_bardiche',
#      'wand_e_wand_e_wand_e']},
#    'achievements': {'ITEMS_CRAFTED': 209,
#     'FOES_DEFEATED': 3662,
#     'SKULL_GAMES': 4,
#     'STONESCRIPT_KEYS': 43,
#     'TRISKELION_USED': 2803,
#     'potions': ['Healing']},
#    'mutator': {'seed': 248252026},
#    'events': {'sIds': []},
#    'custom_quests': {'ftueStep': 'FtueDone',
#     'revealed': ['epic_croaked',
#      'epic_roof_overhead',
#      'epic_remnants_five',
#      'epic_wild_ride',
#      'epic_bad_business'],
#     'active': [{'customQuestId': 'quest_rnd_vigor',
#       'instanceId': 13,
#       'data': {'level': 'null',
#        'element': 'vigor',
#        'progress': 0,
#        'target': 46},
#       'started': 'True',
#       'status': 'Победите 46 силы врагов',
#       'target': 46},
#      {'customQuestId': 'quest_rnd_2',
#       'instanceId': 14,
#       'data': {'level': 'null', 'itemId': 'wand', 'progress': 0, 'target': 8},
#       'started': 'True',
#       'status': 'Смастерите: жезлов, 8 шт. ',
#       'target': 8},
#      {'customQuestId': 'quest_rnd_1',
#       'instanceId': 17,
#       'data': {'level': 'null',
#        'unitType': 'Wound Licker',
#        'progress': 0,
#        'target': 27},
#       'started': 'True',
#       'status': 'Победите 27 врагов: Ранолиз',
#       'target': 27}],
#     'counter': 18,
#     'records': [{'questId': 'quest_2', 'completed': 10},
#      {'questId': 'epic_croaked',
#       'unlocked': 'True',
#       'completed': 1,
#       'cooldown': 1652818058},
#      {'questId': 'epic_roof_overhead',
#       'unlocked': 'True',
#       'completed': 2,
#       'cooldown': 1652784127},
#      {'questId': 'quest_3', 'completed': 23},
#      {'questId': 'epic_remnants_five',
#       'unlocked': 'True',
#       'completed': 1,
#       'cooldown': 1652863741},
#      {'questId': 'quest_1', 'completed': 11},
#      {'questId': 'quest_rnd_1', 'completed': 1},
#      {'questId': 'epic_wild_ride',
#       'unlocked': 'True',
#       'completed': 1,
#       'cooldown': 1656141804},
#      {'questId': 'quest_rnd_fire', 'completed': 3},
#      {'questId': 'epic_bad_business', 'unlocked': 'True'}],
#     'completedCount': 53,
#     'nextSpawnDate': '06/24/2022 18:23:48',
#     'epicSpawnPending': 'False',
#     'basicQuestDate': '08/02/2023 00:00:00',
#     'referral': {'e': '07/22/2023 13:17:31',
#      'h': '01/01/0001 00:00:00',
#      't': 0,
#      'n': 'False'}},
#    'weekly_quest': {'activeQuest': {'type': 'ImproveStars',
#      'hasSeen': 'False',
#      'completed': 'False',
#      'locId': 'rocky_plateau',
#      'goal': 7},
#     'questCount': 38,
#     'expiration': '11/27/2023 00:00:00'},
#    'goals': {'skeleton_arm': {'goal': 2, 'progress': 0},
#     'blade_of_god': {'goal': '-1', 'progress': 0},
#     'cult_mask': {'goal': '-1', 'progress': 0},
#     'fire_talisman': {'goal': '-1', 'progress': 0}},
#    'mind_stone': {'enabled': 'False',
#     'program': ['//import c/cDebug',
#      'import c/cResources',
#      'equipL triskelion',
#      'equipR shield',
#      '',
#      '?loc = Cave & foe.distance < 15',
#      '  equipL sword',
#      '  equipR fire',
#      '?foe = bolesh',
#      '  equipL crossbow 5*',
#      '  ?armor = 0',
#      '    equipR wand',
#      '  :',
#      '    equipR shield',
#      '  ?foe.hp <= 180',
#      '    equip bardiche 6',
#      '',
#      '?loc = crypt & foe.distance < 15 ',
#      '  equipL wand D',
#      '  equipR wand dl',
#      '  ?foe = boss',
#      '    equipR sword',
#      '    equipL fire sword',
#      '',
#      '?loc = forest & foe.distance < 15',
#      '  equip bardiche',
#      '?foe = mushroom_boss',
#      '  equipL hammer',
#      '  equipR shield  ',
#      '?loc = bronze & (foe.distance < 15 | foe = boss)',
#      '  equipL wand e',
#      '  equipR sword',
#      '  //equipR shield aether',
#      '  ?foe = mine_walker',
#      '    equipL hammer',
#      '  ?foe = boss & boss ! bomb_cart',
#      '    equipR wand u',
#      '    equipL crossbow 5',
#      '    ?draw.GetSymbol(21, 18) = ＂/＂',
#      '      equip bardiche',
#      '    :',
#      '      equip crossbow 5*',
#      '  ?ai.enabled = false | ai.paused',
#      '    equipL ouroboros',
#      '    equipR shield',
#      '',
#      '?loc = ridge & foe.distance < 10',
#      '  equip bardiche 6*',
#      '',
#      '?foe ! boo & (loc = deadwood |',
#      '^(loc = temple  & foe.distance < 15))',
#      '  //equipL sword',
#      '  equip bardiche',
#      '',
#      '  equipL sword',
#      '  equipR hammer',
#      '',
#      '  ?foe = serpent',
#      '    equip bardiche 6',
#      '',
#      '?foe = dysangelos',
#      '  equipL sword',
#      '  equipR sword f',
#      '',
#      '?foe = mosquito',
#      '  equipL crossbow 5*',
#      '',
#      '?foe.distance > 20 & hp ! maxhp',
#      '  equipR shield',
#      '  equipL ouroboros  ',
#      '',
#      '?pickup.distance < 6 & foe.distance',
#      '  equipR star',
#      '',
#      '?foe.distance >= 10 & foe.distance < 15 & ',
#      '^loc ! crypt & ',
#      '^(loc ! cave | foe = bolesh & foe.hp <= 180) &',
#      '^foe ! scarab & ',
#      '^foe ! mosquito',
#      '  equipR dashing shield',
#      '',
#      '?hp <= 4',
#      '  activate potion',
#      '',
#      '>`1,10,#red,@BardicheCd@\n@MindCd@',
#      'var BardicheCd = item.GetCooldown(＂bardiche＂)',
#      'BardicheCd = item.GetCooldown(＂bardiche＂)',
#      '?(BardicheCd = 0 | BardicheCd >= 860) & ',
#      '^(foe.hp > 20 | foe.armor > 1) & ',
#      '^foe.distance <= 10',
#      '  equip bardiche 6',
#      '  activate R',
#      '',
#      'var MindCd',
#      'MindCd = item.GetCooldown(＂mind＂)',
#      'var MindDef = 0',
#      '?MindCd = 0 &',
#      '^(foe = bronze_guardian & foe.state = 32)',
#      '  MindDef++',
#      '  ?(MindDef >= 20 & ',
#      '  ^foe = bronze_guardian & armor <= 40)',
#      '    MindDef = 0',
#      '      equipR mind stone',
#      '      activate R',
#      ':',
#      '  MindDef = 0',
#      ''],
#     'saveId': 1}},
#   'encrypted': 'True'},
#  'createdTime': '11/26/2023 01:58:24',
#  'modifiedTime': '11/26/2023 02:14:20',
#  'save_file_41': {'save_id': 41,
#   'uId': 'EJJS0Y',
#   'cId': 'TALQBW',
#   'timestamp': '05/05/2024 12:12:55',
#   'display_name': 'Primary Game',
#   'version': '3.59.2',
#   'is_debug': 'False',
#   'player_name': 'New Story',
#   'player_xp': 0,
#   'player_level': 0,
#   'total_stars': 0,
#   'gearPoints': 5,
#   'left_item_id': '',
#   'left_item_data': '',
#   'right_item_id': 'stones',
#   'right_item_data': {'hI': 'True', 'rng': 0},
#   'big_head': 'False',
#   'hqs': 'False',
#   'progress_data': {'version': '3.59.2',
#    'rng': 1470480018,
#    'hero_settings': {'lastSaveTime': '05/05/2024 12:12:55',
#     'playerName': 'simple one',
#     'bigHead': 'False'},
#    'progress_flags': {'flags': ['show_workstation',
#      'show_items',
#      'show_stone',
#      'show_wood',
#      'rocky_plateau_1',
#      'show_banner',
#      'deadwood_valley_1']},
#    'quest_data': {'available': ['deadwood_valley', 'rocky_plateau'],
#     'star_levels': {},
#     'aspiring_star_ids': [],
#     'aspiring_stars': [],
#     'has_seen': ['find_shelter',
#      'rocky_plateau',
#      'build_door',
#      'deadwood_valley',
#      'build_workstation',
#      'craft_shovel',
#      'craft_hatchet',
#      'prospect_cliff'],
#     'has_played': ['rocky_plateau',
#      'find_shelter',
#      'build_door',
#      'deadwood_valley',
#      'build_workstation',
#      'craft_hatchet',
#      'craft_shovel',
#      'prospect_cliff'],
#     'has_completed': ['rocky_plateau',
#      'find_shelter',
#      'build_door',
#      'deadwood_valley',
#      'build_workstation',
#      'craft_hatchet',
#      'craft_shovel',
#      'prospect_cliff'],
#     'stats': [],
#     'skullnata': '05/05/2024 10:58:08'},
#    'inventory_data': {'Stone': 3,
#     'Wood': 3,
#     'None': 0,
#     'itms': [{'id': 'dirty_sword', 'da': {'hI': 'True', 'rng': 0}},
#      {'id': 'stones', 'da': {'hI': 'True', 'rng': 0}},
#      {'id': 'hatchet_lv1', 'da': {'hI': 'True', 'rng': 0}},
#      {'id': 'shovel_lv1', 'da': {'hI': 'True', 'rng': 0}},
#      {'id': 'sight_stone', 'da': {'hI': 'True', 'rng': 0}}],
#     'rightH': 'stones_lv1',
#     'itmsSeen': ['sight_stone_lv1',
#      'stones_lv1',
#      'hatchet_lv1_lv1',
#      'shovel_lv1_lv1',
#      'dirty_sword_lv1']},
#    'cosmetics': {},
#    'treasure_factory': {'uniqueDate': '04/30/2024 12:10:33',
#     'crystalDate': '04/30/2024 12:10:33',
#     'goldDate': '04/20/2024 12:10:33'},
#    'ui_state': {'screen': 'QuestScreen',
#     'quest_scroll_y': 0,
#     'workstation_scroll_y': 0,
#     'items_scroll_y': 1},
#    'shop_states': {'ids': [],
#     'hasSeenShopkeeper': 'False',
#     'totalPurchases': 0},
#    'crypt_intro': {'timesPlayed': 0,
#     'nextTreasureAvailableDate': '05/05/2024 12:10:33'},
#    'xp': {'currentLevel': 0, 'currentXP': 0},
#    'ouroboros': {'hasBeenTapped': 'False'},
#    'utility_belt': {'loadouts': []},
#    'craft_book': {'discovered_crafts': []},
#    'achievements': {'FOES_DEFEATED': 1},
#    'mutator': {'seed': 808879598},
#    'events': {'sIds': []},
#    'custom_quests': {'ftueStep': 'UnlockBasicQuests',
#     'revealed': [],
#     'active': [],
#     'counter': 0,
#     'completedCount': 0,
#     'nextSpawnDate': '05/05/2024 12:10:33',
#     'epicSpawnPending': 'False',
#     'basicQuestDate': '05/05/2024 00:00:00'},
#    'weekly_quest': {'questCount': 0, 'expiration': '05/05/2024 12:10:33'},
#    'goals': {'skeleton_arm': {'goal': '-1', 'progress': 0},
#     'blade_of_god': {'goal': '-1', 'progress': 0},
#     'cult_mask': {'goal': '-1', 'progress': 0},
#     'fire_talisman': {'goal': '-1', 'progress': 0},
#     'aether_talisman': {'goal': '-1', 'progress': 0}},
#    'subs': {},
#    'prom': {},
#    'leaderboards': {'pId': ''},
#    'mind_stone': {'enabled': 'False',
#     'program': ['// В рабочем состоянии Камень разума постоянно',
#      '// выполняет данные ему указания.',
#      '// Указания должны быть написаны на',
#      '// Камнескрипте.',
#      '// Узнайте больше на:',
#      '// StoneStoryRPG.com/stonescript',
#      '// - Мудрец Безерра',
#      '',
#      '?hp < 7',
#      '  activate potion',
#      '?loc = caves',
#      '  equipL sword',
#      '  equipR shield',
#      '  ?foe = boss',
#      '    equip crossbow']}},
#   'encrypted': 'True'},
#  'STRING_KEYS': ['save_file_42',
#   'save_file_39',
#   'createdTime',
#   'modifiedTime',
#   'save_file_41'],
#  'INT_KEYS': ['save_file_last_id'],
#  'BOOL_KEYS': []}
